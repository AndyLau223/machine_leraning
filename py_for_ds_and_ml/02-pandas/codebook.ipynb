# %% [markdown]
# # Pandas

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/jiancong/code/machine_leraning/.venv/lib/python3.14/site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jiancong/code/machine_leraning/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/jiancong/code/machine_leraning/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp314-cp314-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 46.4 MB/s  0:00:00eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.3

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_data = [10, 20, 30]
arr = np.array(my_data)
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],['USA','Germany','Italy','Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# np.int64(1)

# %%
ser2['Italy']
# Out:
# np.int64(5)

# %%
ser3 = pd.Series(data=labels)

# %%
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64
